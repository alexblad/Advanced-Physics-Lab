# %%
import pandas as pd

#Latest: Magnetic Field (mT) column name of magnetic field data

data_1=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 0_1 Amps.csv")
data_2=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 0_3 Amps.csv")
data_3=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 0_5 Amps.csv")
data_4=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 0_7 Amps.csv")
data_5=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 0_9 Amps.csv")
data_6=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 1_1 Amps.csv")
data_7=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 1_3 Amps.csv")
data_8=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 1_5 Amps.csv")
data_9=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 1_7 Amps.csv")
data_10=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 1_9 Amps.csv")
data_11=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 2_1 Amps.csv")
data_12=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 2_3 Amps.csv")
data_13=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 2_5 Amps.csv")
data_14=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 2_7 Amps.csv")
data_15=pd.read_csv("C:\Magnetic Field Data\Magnetic Field 2_9 Amps.csv")

data_1['Latest: Magnetic Field 0.3']=data_2['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 0.5']=data_3['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 0.7']=data_4['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 0.9']=data_5['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 1.1']=data_6['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 1.3']=data_7['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 1.5']=data_8['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 1.7']=data_9['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 1.9']=data_10['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 2.1']=data_11['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 2.3']=data_12['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 2.5']=data_13['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 2.7']=data_14['Latest: Magnetic Field (mT)']
data_1['Latest: Magnetic Field 2.9']=data_15['Latest: Magnetic Field (mT)']

#old_name=data_1.columns[1]
new_name='Latest: Magnetic Field 0.3'

#column_name_mapping = {old_name: new_name}

data_1.columns.values[1]=new_name
data_1
# Out:
#      Latest: Time (s)  Latest: Magnetic Field 0.3  Latest: Magnetic Field 0.3  \
# 0                0.00                    0.023128                    0.071846
# 1                0.05                    0.023128                    0.071846
# 2                0.10                    0.023128                    0.071846
# 3                0.15                    0.027065                    0.071846
# 4                0.20                    0.023128                    0.067663
# ..                ...                         ...                         ...
# 196              9.80                    0.023128                    0.067663
# 197              9.85                    0.018945                    0.063726
# 198              9.90                    0.023128                    0.067663
# 199              9.95                    0.027065                    0.067663
# 200             10.00                    0.023128                    0.067663
#
# ...

# %%
summary_stats=data_1.describe()
summary_stats.drop('Latest: Time (s)', axis=1, inplace=True)

print(summary_stats)

data_1.to_pickle('Magnetic_Field_Data.pkl')
summary_stats.to_pickle('Summary_Stats.pkl')
# Out:
#        Latest: Magnetic Field 0.3  Latest: Magnetic Field 0.3  \
# count                  201.000000                  201.000000
# mean                     0.019791                    0.065176
# std                      0.003192                    0.004359
# min                      0.015009                    0.055607
# 25%                      0.018945                    0.063726
# 50%                      0.018945                    0.063726
# 75%                      0.023128                    0.067663
# max                      0.027065                    0.076029
#
#        Latest: Magnetic Field 0.5  Latest: Magnetic Field 0.7  \
# count                  201.000000                  201.000000
# mean                     0.143959                    0.179376
# std                      0.005944                    0.009716
# min                      0.132866                    0.161407
# 25%                      0.140985                    0.169527
# ...
